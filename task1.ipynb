# %%
# Import all necessary libaries

import numpy as np
import matplotlib.pyplot as plt

from keras import models, layers, optimizers
from keras.preprocessing.image import ImageDataGenerator 
from keras.layers import Flatten, Dense 
from keras.applications import VGG16

from skimage.transform import resize

from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
# Out:
# Using TensorFlow backend.

# %%
# Datasets path
train_path = 'dataset/train/'
test_path = 'dataset/test'

# Load the VGG model
vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(240, 240, 3))

# Freeze the layers
for layer in vgg_conv.layers:
    layer.trainable = False

# Check the trainable status of the individual layers
for layer in vgg_conv.layers:
    print(layer, layer.trainable)

# Display VGG16
vgg_conv.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 13:37:04.256242 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0618 13:37:04.298055 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0618 13:37:04.311105 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0618 13:37:04.364217 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0618 13:37:05.103089 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0618 13:37:05.105176 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# <keras.engine.input_layer.InputLayer object at 0x7fbcaf237e80> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcaf249048> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcaf249240> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fbcaf249a20> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae785080> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae7360b8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fbcae736a20> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae74e080> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae769128> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae6fbb70> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fbcae714e48> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae72cda0> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae6d92e8> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae6d9b70> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fbcae68dba8> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae68d198> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae635668> False
# <keras.layers.convolutional.Conv2D object at 0x7fbcae650dd8> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fbcae666f28> False
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 240, 240, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 240, 240, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 240, 240, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 120, 120, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 120, 120, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 120, 120, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 60, 60, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 60, 60, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 60, 60, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 60, 60, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 30, 30, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 30, 30, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 30, 30, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 30, 30, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 15, 15, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 15, 15, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(vgg_conv)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(20, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# W0618 13:37:06.958881 140449818982272 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              25691136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                20500
# =================================================================
# Total params: 40,426,324
# Trainable params: 25,711,636
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Padding functions for data preprocessing
def resize_pad(img):
    old_size = img.shape[:2]
    ratio = 240. / max(old_size)
    new_size = tuple([int(x * ratio) for x in old_size])

    img = resize(img, output_shape=new_size, mode='edge', preserve_range=True)

    delta_w = 240 - new_size[1]
    delta_h = 240 - new_size[0]
    padding = ((delta_h // 2, delta_h - (delta_h // 2)), (delta_w // 2, delta_w - (delta_w // 2)), (0, 0))

    img = np.pad(img, padding, 'edge')

    return img

def preprocessing_train(x):
    x = resize_pad(x)
    return x

def preprocessing_val(x):
    x = resize_pad(x)
    return x

# Preapre data generators
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_train,
    rescale=1. / 255,
    zoom_range=0.05,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=90,
    validation_split=0.1
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_val,
    rescale=1. / 255,
    validation_split=0.1
)

train_generator = train_datagen.flow_from_directory(
    train_path,
    color_mode='rgb',
    target_size=(240, 240),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    seed=0
)

validation_generator = test_datagen.flow_from_directory(
    train_path,
    color_mode='rgb',
    target_size=(240, 240),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    seed=0
)

labels = (train_generator.class_indices)
labels = dict((v, k) for k, v in labels.items())

print(labels)
# Out:
# Found 3709 images belonging to 20 classes.
# Found 404 images belonging to 20 classes.
# {0: 'Brick_1x1', 1: 'Brick_1x2', 2: 'Brick_1x3', 3: 'Brick_1x4', 4: 'Brick_2x2', 5: 'Brick_2x2_L', 6: 'Brick_2x2_Slope', 7: 'Brick_2x3', 8: 'Brick_2x4', 9: 'Plate_1x1', 10: 'Plate_1x1_Round', 11: 'Plate_1x1_Slope', 12: 'Plate_1x2', 13: 'Plate_1x2_Grill', 14: 'Plate_1x3', 15: 'Plate_1x4', 16: 'Plate_2x2', 17: 'Plate_2x2_L', 18: 'Plate_2x3', 19: 'Plate_2x4'}

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc', 'top_k_categorical_accuracy'])

# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=50,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# W0618 13:37:07.632616 140449818982272 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0618 13:37:07.994425 140449818982272 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/50
# 116/115 [==============================] - 157s 1s/step - loss: 2.5025 - acc: 0.2525 - top_k_categorical_accuracy: 0.5969 - val_loss: 1.8705 - val_acc: 0.3861 - val_top_k_categorical_accuracy: 0.8119
# Epoch 2/50
# 116/115 [==============================] - 127s 1s/step - loss: 1.8410 - acc: 0.4033 - top_k_categorical_accuracy: 0.8108 - val_loss: 1.6396 - val_acc: 0.4752 - val_top_k_categorical_accuracy: 0.8391
# Epoch 3/50
# 116/115 [==============================] - 124s 1s/step - loss: 1.5462 - acc: 0.4926 - top_k_categorical_accuracy: 0.8736 - val_loss: 1.4395 - val_acc: 0.5644 - val_top_k_categorical_accuracy: 0.8861
# Epoch 4/50
# 116/115 [==============================] - 124s 1s/step - loss: 1.3831 - acc: 0.5441 - top_k_categorical_accuracy: 0.9052 - val_loss: 1.4343 - val_acc: 0.5272 - val_top_k_categorical_accuracy: 0.8960
# Epoch 5/50
# 116/115 [==============================] - 125s 1s/step - loss: 1.2824 - acc: 0.5708 - top_k_categorical_accuracy: 0.9213 - val_loss: 1.1916 - val_acc: 0.6782 - val_top_k_categorical_accuracy: 0.9282
# Epoch 6/50
# 116/115 [==============================] - 127s 1s/step - loss: 1.1706 - acc: 0.6059 - top_k_categorical_accuracy: 0.9334 - val_loss: 1.1313 - val_acc: 0.6634 - val_top_k_categorical_accuracy: 0.9307
# Epoch 7/50
# 116/115 [==============================] - 126s 1s/step - loss: 1.1328 - acc: 0.6085 - top_k_categorical_accuracy: 0.9410 - val_loss: 1.1179 - val_acc: 0.6559 - val_top_k_categorical_accuracy: 0.9332
# Epoch 8/50
# 116/115 [==============================] - 126s 1s/step - loss: 1.0475 - acc: 0.6424 - top_k_categorical_accuracy: 0.9496 - val_loss: 1.0485 - val_acc: 0.6708 - val_top_k_categorical_accuracy: 0.9356
# Epoch 9/50
# 116/115 [==============================] - 125s 1s/step - loss: 0.9960 - acc: 0.6606 - top_k_categorical_accuracy: 0.9563 - val_loss: 1.0456 - val_acc: 0.6832 - val_top_k_categorical_accuracy: 0.9356
# Epoch 10/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.9523 - acc: 0.6789 - top_k_categorical_accuracy: 0.9558 - val_loss: 0.9816 - val_acc: 0.7030 - val_top_k_categorical_accuracy: 0.9505
# Epoch 11/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.9167 - acc: 0.6864 - top_k_categorical_accuracy: 0.9620 - val_loss: 0.9472 - val_acc: 0.7252 - val_top_k_categorical_accuracy: 0.9455
# Epoch 12/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.8669 - acc: 0.7045 - top_k_categorical_accuracy: 0.9701 - val_loss: 0.8792 - val_acc: 0.7649 - val_top_k_categorical_accuracy: 0.9554
# Epoch 13/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.8386 - acc: 0.7126 - top_k_categorical_accuracy: 0.9738 - val_loss: 0.8739 - val_acc: 0.7351 - val_top_k_categorical_accuracy: 0.9579
# Epoch 14/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.8016 - acc: 0.7385 - top_k_categorical_accuracy: 0.9763 - val_loss: 0.7948 - val_acc: 0.7698 - val_top_k_categorical_accuracy: 0.9579
# Epoch 15/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.7895 - acc: 0.7312 - top_k_categorical_accuracy: 0.9727 - val_loss: 0.8290 - val_acc: 0.7574 - val_top_k_categorical_accuracy: 0.9505
# Epoch 16/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.7540 - acc: 0.7541 - top_k_categorical_accuracy: 0.9779 - val_loss: 0.7771 - val_acc: 0.7723 - val_top_k_categorical_accuracy: 0.9604
# Epoch 17/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.7183 - acc: 0.7600 - top_k_categorical_accuracy: 0.9809 - val_loss: 0.7706 - val_acc: 0.7871 - val_top_k_categorical_accuracy: 0.9505
# Epoch 18/50
# 116/115 [==============================] - 125s 1s/step - loss: 0.7099 - acc: 0.7619 - top_k_categorical_accuracy: 0.9776 - val_loss: 0.7737 - val_acc: 0.7822 - val_top_k_categorical_accuracy: 0.9678
# Epoch 19/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.6891 - acc: 0.7725 - top_k_categorical_accuracy: 0.9844 - val_loss: 0.7418 - val_acc: 0.7871 - val_top_k_categorical_accuracy: 0.9604
# Epoch 20/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.6797 - acc: 0.7673 - top_k_categorical_accuracy: 0.9841 - val_loss: 0.7520 - val_acc: 0.7822 - val_top_k_categorical_accuracy: 0.9629
# Epoch 21/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.6742 - acc: 0.7741 - top_k_categorical_accuracy: 0.9811 - val_loss: 0.7466 - val_acc: 0.7946 - val_top_k_categorical_accuracy: 0.9629
# Epoch 22/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.6300 - acc: 0.7908 - top_k_categorical_accuracy: 0.9825 - val_loss: 0.7300 - val_acc: 0.7847 - val_top_k_categorical_accuracy: 0.9653
# Epoch 23/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.6213 - acc: 0.7885 - top_k_categorical_accuracy: 0.9857 - val_loss: 0.7058 - val_acc: 0.8144 - val_top_k_categorical_accuracy: 0.9703
# Epoch 24/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.6068 - acc: 0.7897 - top_k_categorical_accuracy: 0.9870 - val_loss: 0.6658 - val_acc: 0.8193 - val_top_k_categorical_accuracy: 0.9703
# Epoch 25/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.6047 - acc: 0.8004 - top_k_categorical_accuracy: 0.9838 - val_loss: 0.6575 - val_acc: 0.8267 - val_top_k_categorical_accuracy: 0.9703
# Epoch 26/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5830 - acc: 0.8083 - top_k_categorical_accuracy: 0.9871 - val_loss: 0.7701 - val_acc: 0.7797 - val_top_k_categorical_accuracy: 0.9653
# Epoch 27/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5822 - acc: 0.8007 - top_k_categorical_accuracy: 0.9865 - val_loss: 0.7137 - val_acc: 0.8069 - val_top_k_categorical_accuracy: 0.9604
# Epoch 28/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5630 - acc: 0.8153 - top_k_categorical_accuracy: 0.9873 - val_loss: 0.7520 - val_acc: 0.7970 - val_top_k_categorical_accuracy: 0.9604
# Epoch 29/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.5432 - acc: 0.8207 - top_k_categorical_accuracy: 0.9890 - val_loss: 0.6639 - val_acc: 0.7970 - val_top_k_categorical_accuracy: 0.9703
# Epoch 30/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.5387 - acc: 0.8131 - top_k_categorical_accuracy: 0.9900 - val_loss: 0.6230 - val_acc: 0.8317 - val_top_k_categorical_accuracy: 0.9678
# Epoch 31/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.5365 - acc: 0.8187 - top_k_categorical_accuracy: 0.9895 - val_loss: 0.6579 - val_acc: 0.8193 - val_top_k_categorical_accuracy: 0.9678
# Epoch 32/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5392 - acc: 0.8266 - top_k_categorical_accuracy: 0.9884 - val_loss: 0.6385 - val_acc: 0.8020 - val_top_k_categorical_accuracy: 0.9777
# Epoch 33/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5054 - acc: 0.8301 - top_k_categorical_accuracy: 0.9897 - val_loss: 0.6629 - val_acc: 0.8317 - val_top_k_categorical_accuracy: 0.9653
# Epoch 34/50
# 116/115 [==============================] - 125s 1s/step - loss: 0.5173 - acc: 0.8208 - top_k_categorical_accuracy: 0.9903 - val_loss: 0.6033 - val_acc: 0.8515 - val_top_k_categorical_accuracy: 0.9752
# Epoch 35/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.5132 - acc: 0.8283 - top_k_categorical_accuracy: 0.9908 - val_loss: 0.6132 - val_acc: 0.8342 - val_top_k_categorical_accuracy: 0.9653
# Epoch 36/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.4966 - acc: 0.8374 - top_k_categorical_accuracy: 0.9919 - val_loss: 0.6037 - val_acc: 0.8441 - val_top_k_categorical_accuracy: 0.9728
# Epoch 37/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.5004 - acc: 0.8374 - top_k_categorical_accuracy: 0.9900 - val_loss: 0.5817 - val_acc: 0.8366 - val_top_k_categorical_accuracy: 0.9752
# Epoch 38/50
# 116/115 [==============================] - 123s 1s/step - loss: 0.4659 - acc: 0.8405 - top_k_categorical_accuracy: 0.9906 - val_loss: 0.6016 - val_acc: 0.8391 - val_top_k_categorical_accuracy: 0.9653
# Epoch 39/50
# 116/115 [==============================] - 124s 1s/step - loss: 0.4644 - acc: 0.8415 - top_k_categorical_accuracy: 0.9925 - val_loss: 0.5630 - val_acc: 0.8441 - val_top_k_categorical_accuracy: 0.9802
# Epoch 40/50
# 116/115 [==============================] - 122s 1s/step - loss: 0.4654 - acc: 0.8431 - top_k_categorical_accuracy: 0.9927 - val_loss: 0.5321 - val_acc: 0.8540 - val_top_k_categorical_accuracy: 0.9777
# Epoch 41/50
# 116/115 [==============================] - 125s 1s/step - loss: 0.4520 - acc: 0.8423 - top_k_categorical_accuracy: 0.9916 - val_loss: 0.5519 - val_acc: 0.8614 - val_top_k_categorical_accuracy: 0.9777
# Epoch 42/50
# 116/115 [==============================] - 127s 1s/step - loss: 0.4608 - acc: 0.8453 - top_k_categorical_accuracy: 0.9925 - val_loss: 0.6023 - val_acc: 0.8317 - val_top_k_categorical_accuracy: 0.9777
# Epoch 43/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.4544 - acc: 0.8491 - top_k_categorical_accuracy: 0.9919 - val_loss: 0.5724 - val_acc: 0.8317 - val_top_k_categorical_accuracy: 0.9703
# Epoch 44/50
# 116/115 [==============================] - 125s 1s/step - loss: 0.4439 - acc: 0.8482 - top_k_categorical_accuracy: 0.9949 - val_loss: 0.5454 - val_acc: 0.8441 - val_top_k_categorical_accuracy: 0.9728
# Epoch 45/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.4389 - acc: 0.8499 - top_k_categorical_accuracy: 0.9919 - val_loss: 0.5600 - val_acc: 0.8441 - val_top_k_categorical_accuracy: 0.9752
# Epoch 46/50
# 116/115 [==============================] - 127s 1s/step - loss: 0.4156 - acc: 0.8623 - top_k_categorical_accuracy: 0.9943 - val_loss: 0.5711 - val_acc: 0.8391 - val_top_k_categorical_accuracy: 0.9752
# Epoch 47/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.4321 - acc: 0.8523 - top_k_categorical_accuracy: 0.9927 - val_loss: 0.5926 - val_acc: 0.8416 - val_top_k_categorical_accuracy: 0.9752
# Epoch 48/50
# 116/115 [==============================] - 127s 1s/step - loss: 0.4143 - acc: 0.8530 - top_k_categorical_accuracy: 0.9935 - val_loss: 0.5650 - val_acc: 0.8540 - val_top_k_categorical_accuracy: 0.9802
# Epoch 49/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.4296 - acc: 0.8509 - top_k_categorical_accuracy: 0.9922 - val_loss: 0.5985 - val_acc: 0.8416 - val_top_k_categorical_accuracy: 0.9703
# Epoch 50/50
# 116/115 [==============================] - 126s 1s/step - loss: 0.4099 - acc: 0.8652 - top_k_categorical_accuracy: 0.9933 - val_loss: 0.5184 - val_acc: 0.8812 - val_top_k_categorical_accuracy: 0.9802

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
top_k_categorical_accuracy = history.history['top_k_categorical_accuracy']
val_top_k_categorical_accuracy = history.history['val_top_k_categorical_accuracy']

 
epochs = range(len(acc))
 
# Top-1 accuracy
plt.plot(epochs, acc, 'b', label='Training acc top-1')
plt.plot(epochs, val_acc, 'r', label='Validation acc top-1')
plt.title('Training and validation accuracy top-1')
plt.legend()
 
plt.figure()

# Top-5 accuracy
plt.plot(epochs, top_k_categorical_accuracy, 'b', label='Training acc top-5')
plt.plot(epochs, val_top_k_categorical_accuracy, 'r', label='Validation acc top-5')
plt.title('Training and validation accuracy top-5')
plt.legend()

plt.figure()

# Loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
# Create a generator for test dataset
validation_generator = test_datagen.flow_from_directory(
        test_path,
        target_size=(240, 240),
        batch_size=10,
        class_mode='categorical',
        shuffle=False)
 

ground_truth = validation_generator.classes
 
# Labels into dictionary
label2index = validation_generator.class_indices
idx2label = dict((v,k) for k,v in label2index.items())
 
# Predictions
predictions = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
predicted_classes = np.argmax(predictions,axis=1)
# Out:
# Found 467 images belonging to 20 classes.
# 47/46 [==============================] - 9s 183ms/step

# %%
# Binarize and transpose results and ground truth
y = label_binarize(ground_truth, classes=[x for x in range(20)])
y_pred = label_binarize(predicted_classes, classes=[x for x in range(20)])
y = y.T
y_pred = y_pred.T

# Display all roc's curves
for i in range(20):
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(y[i], y_pred[i])

  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(i+1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve for class '+ idx2label[i])
  plt.legend(loc='best')
  plt.show()

# %%
good_predictions = 0
for prediction, label in zip(predicted_classes, ground_truth):
  if prediction == label:
    good_predictions += 1

result = good_predictions/len(predicted_classes)

print("Result: ", result)
print("Good predictions: ", good_predictions)
print("All predictions: ", len(predicted_classes))
# Out:
# Result:  0.8865096359743041
# Good predictions:  414
# All predictions:  467
