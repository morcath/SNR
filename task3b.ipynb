# %%
# Import all necessary libaries

import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Flatten, MaxPooling2D, Dense, DepthwiseConv2D, LeakyReLU, Add, Dropout
from keras.models import Model
from keras import models, layers, optimizers
from skimage.transform import resize

# %%
# Datasets path

train_path = 'dataset/train/'
test_path = 'dataset/test/'

# Padding functions for data preprocessing

def resize_pad(img):
    old_size = img.shape[:2]
    ratio = 200. / max(old_size)
    new_size = tuple([int(x * ratio) for x in old_size])

    img = resize(img, output_shape=new_size, mode='edge', preserve_range=True)

    delta_w = 200 - new_size[1]
    delta_h = 200 - new_size[0]
    padding = ((delta_h // 2, delta_h - (delta_h // 2)), (delta_w // 2, delta_w - (delta_w // 2)), (0, 0))

    img = np.pad(img, padding, 'edge')

    return img

def preprocessing_train(x):
    x = resize_pad(x)
    return x


def preprocessing_val(x):
    x = resize_pad(x)
    return x

# Preapre data generators

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_train,
    rescale=1. / 255,
    zoom_range=0.05,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=90,
    validation_split=0.1
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing_val,
    rescale=1. / 255,
    validation_split=0.1
)

train_generator = train_datagen.flow_from_directory(
    train_path,
    color_mode='grayscale',
    target_size=(200, 200),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    seed=0
)

validation_generator = test_datagen.flow_from_directory(
    train_path,
    color_mode='grayscale',
    target_size=(200, 200),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    seed=0
)

labels = (train_generator.class_indices)
labels = dict((v, k) for k, v in labels.items())

print(labels)
# Out:
# Found 3709 images belonging to 20 classes.
# Found 404 images belonging to 20 classes.
# {0: 'Brick_1x1', 1: 'Brick_1x2', 2: 'Brick_1x3', 3: 'Brick_1x4', 4: 'Brick_2x2', 5: 'Brick_2x2_L', 6: 'Brick_2x2_Slope', 7: 'Brick_2x3', 8: 'Brick_2x4', 9: 'Plate_1x1', 10: 'Plate_1x1_Round', 11: 'Plate_1x1_Slope', 12: 'Plate_1x2', 13: 'Plate_1x2_Grill', 14: 'Plate_1x3', 15: 'Plate_1x4', 16: 'Plate_2x2', 17: 'Plate_2x2_L', 18: 'Plate_2x3', 19: 'Plate_2x4'}

# %%
inputs = Input(shape=(200, 200, 1))

net = Conv2D(filters=64, kernel_size=3, padding='same')(inputs)
net = LeakyReLU()(net)
net = MaxPooling2D()(net)

net = Conv2D(filters=64, kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D()(net)

net = Conv2D(filters=64, kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D()(net)

shortcut = net

net = DepthwiseConv2D(kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)

net = Conv2D(filters=64, kernel_size=1, padding='same')(net)
net = LeakyReLU()(net)

net = DepthwiseConv2D(kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)

net = Conv2D(filters=64, kernel_size=1, padding='same')(net)
net = LeakyReLU()(net)

net = Add()([shortcut, net])

net = Conv2D(filters=64, kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D()(net)

net = Conv2D(filters=64, kernel_size=3, padding='same')(net)
net = LeakyReLU()(net)
net = MaxPooling2D()(net)

# net = DepthwiseConv2D(kernel_size=3, padding='same')(net)
# net = LeakyReLU()(net)

# net = Conv2D(filters=128, kernel_size=1, padding='same')(net)
# net = LeakyReLU()(net)

net = Flatten()(net)

net = Dense(128, activation='relu')(net)

# net = Dense(64, activation='relu')(net)

outputs = Dense(20, activation='softmax')(net)

model = Model(inputs=inputs, outputs=outputs)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc', 'top_k_categorical_accuracy'])

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0618 20:53:50.125973 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0618 20:53:50.176388 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0618 20:53:50.185009 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0618 20:53:50.216761 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0618 20:53:50.361413 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0618 20:53:50.383337 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 200, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 200, 200, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 100, 100, 64) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 64) 36928       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 100, 100, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 50, 50, 64)   0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 50, 50, 64)   36928       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 50, 50, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 25, 25, 64)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 25, 25, 64)   640         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 25, 25, 64)   0           depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 25, 25, 64)   4160        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 25, 25, 64)   640         leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 25, 25, 64)   0           depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 25, 64)   4160        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 25, 25, 64)   0           max_pooling2d_3[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 25, 25, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 25, 25, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 64)   0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 12, 64)   36928       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 12, 12, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 6, 6, 64)     0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2304)         0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          295040      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           2580        dense_1[0][0]
# ==================================================================================================
# Total params: 455,572
# Trainable params: 455,572
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit_generator(
    train_generator, 
    steps_per_epoch=train_generator.samples/train_generator.batch_size,
    epochs=50, 
    validation_data=validation_generator,
    validation_steps=validation_generator.samples/validation_generator.batch_size,
    verbose=1)
# Out:
# W0618 20:53:50.528405 140591047841664 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0618 20:53:50.652717 140591047841664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/50
# 116/115 [==============================] - 39s 334ms/step - loss: 2.9860 - acc: 0.0752 - top_k_categorical_accuracy: 0.3003 - val_loss: 2.9605 - val_acc: 0.1040 - val_top_k_categorical_accuracy: 0.3441
# Epoch 2/50
# 116/115 [==============================] - 30s 261ms/step - loss: 2.8477 - acc: 0.1060 - top_k_categorical_accuracy: 0.4191 - val_loss: 2.5895 - val_acc: 0.2129 - val_top_k_categorical_accuracy: 0.5668
# Epoch 3/50
# 116/115 [==============================] - 31s 266ms/step - loss: 2.4610 - acc: 0.2016 - top_k_categorical_accuracy: 0.5959 - val_loss: 2.3556 - val_acc: 0.2921 - val_top_k_categorical_accuracy: 0.6708
# Epoch 4/50
# 116/115 [==============================] - 31s 265ms/step - loss: 2.2232 - acc: 0.2780 - top_k_categorical_accuracy: 0.6951 - val_loss: 2.2715 - val_acc: 0.3391 - val_top_k_categorical_accuracy: 0.6906
# Epoch 5/50
# 116/115 [==============================] - 30s 260ms/step - loss: 2.0495 - acc: 0.3278 - top_k_categorical_accuracy: 0.7455 - val_loss: 2.0607 - val_acc: 0.3837 - val_top_k_categorical_accuracy: 0.7500
# Epoch 6/50
# 116/115 [==============================] - 31s 263ms/step - loss: 1.9199 - acc: 0.3658 - top_k_categorical_accuracy: 0.7862 - val_loss: 1.8507 - val_acc: 0.4653 - val_top_k_categorical_accuracy: 0.8020
# Epoch 7/50
# 116/115 [==============================] - 30s 262ms/step - loss: 1.7531 - acc: 0.4249 - top_k_categorical_accuracy: 0.8245 - val_loss: 1.8332 - val_acc: 0.4554 - val_top_k_categorical_accuracy: 0.8193
# Epoch 8/50
# 116/115 [==============================] - 30s 261ms/step - loss: 1.6572 - acc: 0.4505 - top_k_categorical_accuracy: 0.8571 - val_loss: 1.8337 - val_acc: 0.4381 - val_top_k_categorical_accuracy: 0.7995
# Epoch 9/50
# 116/115 [==============================] - 31s 265ms/step - loss: 1.5887 - acc: 0.4719 - top_k_categorical_accuracy: 0.8760 - val_loss: 1.5369 - val_acc: 0.5421 - val_top_k_categorical_accuracy: 0.8787
# Epoch 10/50
# 116/115 [==============================] - 30s 260ms/step - loss: 1.4195 - acc: 0.5285 - top_k_categorical_accuracy: 0.8974 - val_loss: 1.4692 - val_acc: 0.5693 - val_top_k_categorical_accuracy: 0.9134
# Epoch 11/50
# 116/115 [==============================] - 30s 258ms/step - loss: 1.2829 - acc: 0.5770 - top_k_categorical_accuracy: 0.9220 - val_loss: 1.3559 - val_acc: 0.5792 - val_top_k_categorical_accuracy: 0.9257
# Epoch 12/50
# 116/115 [==============================] - 30s 261ms/step - loss: 1.1769 - acc: 0.5949 - top_k_categorical_accuracy: 0.9385 - val_loss: 1.3797 - val_acc: 0.5248 - val_top_k_categorical_accuracy: 0.9356
# Epoch 13/50
# 116/115 [==============================] - 30s 256ms/step - loss: 1.0856 - acc: 0.6261 - top_k_categorical_accuracy: 0.9468 - val_loss: 1.6450 - val_acc: 0.4703 - val_top_k_categorical_accuracy: 0.9010
# Epoch 14/50
# 116/115 [==============================] - 30s 258ms/step - loss: 1.0379 - acc: 0.6448 - top_k_categorical_accuracy: 0.9582 - val_loss: 1.4380 - val_acc: 0.5272 - val_top_k_categorical_accuracy: 0.9282
# Epoch 15/50
# 116/115 [==============================] - 30s 257ms/step - loss: 1.0016 - acc: 0.6565 - top_k_categorical_accuracy: 0.9649 - val_loss: 1.0441 - val_acc: 0.6535 - val_top_k_categorical_accuracy: 0.9629
# Epoch 16/50
# 116/115 [==============================] - 30s 256ms/step - loss: 0.9266 - acc: 0.6848 - top_k_categorical_accuracy: 0.9682 - val_loss: 1.6946 - val_acc: 0.4604 - val_top_k_categorical_accuracy: 0.9233
# Epoch 17/50
# 116/115 [==============================] - 30s 259ms/step - loss: 0.9094 - acc: 0.6856 - top_k_categorical_accuracy: 0.9758 - val_loss: 1.3124 - val_acc: 0.5916 - val_top_k_categorical_accuracy: 0.9406
# Epoch 18/50
# 116/115 [==============================] - 30s 255ms/step - loss: 0.8690 - acc: 0.7000 - top_k_categorical_accuracy: 0.9714 - val_loss: 1.5558 - val_acc: 0.5569 - val_top_k_categorical_accuracy: 0.9381
# Epoch 19/50
# 116/115 [==============================] - 29s 254ms/step - loss: 0.8364 - acc: 0.7052 - top_k_categorical_accuracy: 0.9744 - val_loss: 1.6102 - val_acc: 0.5223 - val_top_k_categorical_accuracy: 0.9431
# Epoch 20/50
# 116/115 [==============================] - 30s 256ms/step - loss: 0.8078 - acc: 0.7292 - top_k_categorical_accuracy: 0.9746 - val_loss: 1.2836 - val_acc: 0.6114 - val_top_k_categorical_accuracy: 0.9431
# Epoch 21/50
# 116/115 [==============================] - 30s 255ms/step - loss: 0.7825 - acc: 0.7361 - top_k_categorical_accuracy: 0.9776 - val_loss: 1.3426 - val_acc: 0.5866 - val_top_k_categorical_accuracy: 0.9579
# Epoch 22/50
# 116/115 [==============================] - 30s 258ms/step - loss: 0.7299 - acc: 0.7374 - top_k_categorical_accuracy: 0.9820 - val_loss: 2.4142 - val_acc: 0.4035 - val_top_k_categorical_accuracy: 0.9010
# Epoch 23/50
# 116/115 [==============================] - 30s 256ms/step - loss: 0.7574 - acc: 0.7392 - top_k_categorical_accuracy: 0.9808 - val_loss: 1.5399 - val_acc: 0.5891 - val_top_k_categorical_accuracy: 0.9530
# Epoch 24/50
# 116/115 [==============================] - 30s 255ms/step - loss: 0.6992 - acc: 0.7492 - top_k_categorical_accuracy: 0.9814 - val_loss: 1.4311 - val_acc: 0.5545 - val_top_k_categorical_accuracy: 0.9554
# Epoch 25/50
# 116/115 [==============================] - 30s 257ms/step - loss: 0.6613 - acc: 0.7711 - top_k_categorical_accuracy: 0.9865 - val_loss: 1.6608 - val_acc: 0.4975 - val_top_k_categorical_accuracy: 0.9604
# Epoch 26/50
# 116/115 [==============================] - 29s 254ms/step - loss: 0.6509 - acc: 0.7780 - top_k_categorical_accuracy: 0.9849 - val_loss: 1.5187 - val_acc: 0.5446 - val_top_k_categorical_accuracy: 0.9530
# Epoch 27/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.6487 - acc: 0.7772 - top_k_categorical_accuracy: 0.9860 - val_loss: 1.2420 - val_acc: 0.6485 - val_top_k_categorical_accuracy: 0.9455
# Epoch 28/50
# 116/115 [==============================] - 29s 254ms/step - loss: 0.6552 - acc: 0.7706 - top_k_categorical_accuracy: 0.9860 - val_loss: 1.2504 - val_acc: 0.6411 - val_top_k_categorical_accuracy: 0.9579
# Epoch 29/50
# 116/115 [==============================] - 29s 250ms/step - loss: 0.6225 - acc: 0.7835 - top_k_categorical_accuracy: 0.9879 - val_loss: 1.5062 - val_acc: 0.5545 - val_top_k_categorical_accuracy: 0.9505
# Epoch 30/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.5995 - acc: 0.7896 - top_k_categorical_accuracy: 0.9884 - val_loss: 1.9242 - val_acc: 0.4653 - val_top_k_categorical_accuracy: 0.9208
# Epoch 31/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.5924 - acc: 0.7938 - top_k_categorical_accuracy: 0.9911 - val_loss: 1.5632 - val_acc: 0.5644 - val_top_k_categorical_accuracy: 0.9480
# Epoch 32/50
# 116/115 [==============================] - 29s 254ms/step - loss: 0.5792 - acc: 0.7965 - top_k_categorical_accuracy: 0.9903 - val_loss: 1.3678 - val_acc: 0.5965 - val_top_k_categorical_accuracy: 0.9554
# Epoch 33/50
# 116/115 [==============================] - 30s 257ms/step - loss: 0.5463 - acc: 0.8107 - top_k_categorical_accuracy: 0.9927 - val_loss: 1.2030 - val_acc: 0.6559 - val_top_k_categorical_accuracy: 0.9678
# Epoch 34/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.5415 - acc: 0.8164 - top_k_categorical_accuracy: 0.9927 - val_loss: 1.8341 - val_acc: 0.4950 - val_top_k_categorical_accuracy: 0.9431
# Epoch 35/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.5459 - acc: 0.8070 - top_k_categorical_accuracy: 0.9925 - val_loss: 1.5453 - val_acc: 0.5495 - val_top_k_categorical_accuracy: 0.9579
# Epoch 36/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.5302 - acc: 0.8155 - top_k_categorical_accuracy: 0.9911 - val_loss: 1.8826 - val_acc: 0.5421 - val_top_k_categorical_accuracy: 0.9455
# Epoch 37/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.5197 - acc: 0.8164 - top_k_categorical_accuracy: 0.9925 - val_loss: 1.0740 - val_acc: 0.6460 - val_top_k_categorical_accuracy: 0.9703
# Epoch 38/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.5265 - acc: 0.8199 - top_k_categorical_accuracy: 0.9911 - val_loss: 2.0007 - val_acc: 0.5644 - val_top_k_categorical_accuracy: 0.9406
# Epoch 39/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.5120 - acc: 0.8224 - top_k_categorical_accuracy: 0.9933 - val_loss: 1.4524 - val_acc: 0.6163 - val_top_k_categorical_accuracy: 0.9579
# Epoch 40/50
# 116/115 [==============================] - 29s 252ms/step - loss: 0.4926 - acc: 0.8345 - top_k_categorical_accuracy: 0.9919 - val_loss: 1.9599 - val_acc: 0.5545 - val_top_k_categorical_accuracy: 0.9332
# Epoch 41/50
# 116/115 [==============================] - 30s 255ms/step - loss: 0.4708 - acc: 0.8366 - top_k_categorical_accuracy: 0.9930 - val_loss: 1.3636 - val_acc: 0.6411 - val_top_k_categorical_accuracy: 0.9604
# Epoch 42/50
# 116/115 [==============================] - 29s 253ms/step - loss: 0.4608 - acc: 0.8398 - top_k_categorical_accuracy: 0.9943 - val_loss: 1.9285 - val_acc: 0.5718 - val_top_k_categorical_accuracy: 0.9505
# Epoch 43/50
# 116/115 [==============================] - 30s 256ms/step - loss: 0.4518 - acc: 0.8487 - top_k_categorical_accuracy: 0.9943 - val_loss: 1.2905 - val_acc: 0.6064 - val_top_k_categorical_accuracy: 0.9653
# Epoch 44/50
# 116/115 [==============================] - 30s 255ms/step - loss: 0.4247 - acc: 0.8559 - top_k_categorical_accuracy: 0.9938 - val_loss: 1.6102 - val_acc: 0.6089 - val_top_k_categorical_accuracy: 0.9579
# Epoch 45/50
# 116/115 [==============================] - 29s 252ms/step - loss: 0.4223 - acc: 0.8509 - top_k_categorical_accuracy: 0.9970 - val_loss: 1.6764 - val_acc: 0.6040 - val_top_k_categorical_accuracy: 0.9530
# Epoch 46/50
# 116/115 [==============================] - 29s 249ms/step - loss: 0.4530 - acc: 0.8388 - top_k_categorical_accuracy: 0.9968 - val_loss: 0.8538 - val_acc: 0.7475 - val_top_k_categorical_accuracy: 0.9802
# Epoch 47/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.4158 - acc: 0.8555 - top_k_categorical_accuracy: 0.9957 - val_loss: 1.4119 - val_acc: 0.6411 - val_top_k_categorical_accuracy: 0.9554
# Epoch 48/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.4169 - acc: 0.8528 - top_k_categorical_accuracy: 0.9965 - val_loss: 1.8615 - val_acc: 0.5817 - val_top_k_categorical_accuracy: 0.9455
# Epoch 49/50
# 116/115 [==============================] - 29s 250ms/step - loss: 0.3886 - acc: 0.8633 - top_k_categorical_accuracy: 0.9965 - val_loss: 1.3889 - val_acc: 0.6460 - val_top_k_categorical_accuracy: 0.9629
# Epoch 50/50
# 116/115 [==============================] - 29s 251ms/step - loss: 0.4323 - acc: 0.8435 - top_k_categorical_accuracy: 0.9973 - val_loss: 1.5804 - val_acc: 0.6312 - val_top_k_categorical_accuracy: 0.9480

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
top_k_categorical_accuracy = history.history['top_k_categorical_accuracy']
val_top_k_categorical_accuracy = history.history['val_top_k_categorical_accuracy']

 
epochs = range(len(acc))
 
# Top-1 accuracy
plt.plot(epochs, acc, 'b', label='Training acc top-1')
plt.plot(epochs, val_acc, 'r', label='Validation acc top-1')
plt.title('Training and validation accuracy top-1')
plt.legend()
 
plt.figure()

# Top-5 accuracy
plt.plot(epochs, top_k_categorical_accuracy, 'b', label='Training acc top-5')
plt.plot(epochs, val_top_k_categorical_accuracy, 'r', label='Validation acc top-5')
plt.title('Training and validation accuracy top-5')
plt.legend()

plt.figure()

# Loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
# Create a generator for test dataset
validation_generator = test_datagen.flow_from_directory(
        test_path,
        color_mode='grayscale',
        target_size=(200, 200),
        batch_size=10,
        class_mode='categorical',
        shuffle=False)
 

ground_truth = validation_generator.classes
 
# Labels into dictionary
label2index = validation_generator.class_indices
idx2label = dict((v,k) for k,v in label2index.items())
 
# Predictions
predictions = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size,verbose=1)
predicted_classes = np.argmax(predictions,axis=1)
# Out:
# Found 467 images belonging to 20 classes.
# 47/46 [==============================] - 2s 45ms/step

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

# Binarize and transpose results and ground truth
y = label_binarize(ground_truth, classes=[x for x in range(20)])
y_pred = label_binarize(predicted_classes, classes=[x for x in range(20)])
y = y.T
y_pred = y_pred.T

# Display all roc's curves
for i in range(20):
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(y[i], y_pred[i])

  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(i+1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve for class '+ idx2label[i])
  plt.legend(loc='best')
  plt.show()

# %%
good_predictions = 0
for prediction, label in zip(predicted_classes, ground_truth):
  if prediction == label:
    good_predictions += 1

result = good_predictions/len(predicted_classes)

print("Result: ", result)
print("Good predictions: ", good_predictions)
print("All predictions: ", len(predicted_classes))
# Out:
# Result:  0.6316916488222698
# Good predictions:  295
# All predictions:  467
